# %%
import numpy as np
import cv2
import mediapipe as mp
from mediapipe.tasks import python
from mediapipe.tasks.python import vision

# %%
import mediapipe as mp
from mediapipe.tasks import python
from mediapipe.tasks.python import vision
import tensorflow as tf

# %%
model_path = "C:/Users/lamtr/Documents/my_model_waste.h5"

# %%
from PIL import Image
from keras import models
model = models.load_model(model_path, custom_objects=None, compile=True, options=None)
video = cv2.VideoCapture(0)
text_color = (206,235,135)
org = (50,50)
font = cv2.FONT_HERSHEY_SIMPLEX
fontScale = 1
thickness = 3
class_list = ['Recycle','Organic','No']

def check_label (predicted_class):
    if predicted_class == '0':
        print('You need to recycle it')
    elif predicted_class == '1':
        print('No recycling!!!')
    else :
        print('Please throw it into the trash')
while True:
    ret, image_np = video.read()
    image_np = cv2.flip(image_np, 1)
    image_resized = cv2.resize(image_np, (80, 80))
    img_array = tf.expand_dims(image_resized, 0)
    predict = model.predict(img_array)
    predict_index = np.argmax(predict[0], axis=0)
    predicted_class = class_list[predict_index]
    image_np = cv2.putText(image_np, "Image Classification Output: " + str(predicted_class), org,
      font, fontScale, text_color, thickness, cv2.LINE_AA)
    print(predict)
        
    cv2.imshow('Capturing', image_np)
    check_label(predicted_class)
    key = cv2.waitKey(1)
    if key == ord('q'):
        break

video.release()
cv2.destroyAllWindows()
# Out:
# WARNING:tensorflow:5 out of the last 105 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000028B65A19E40> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 1s 846ms/step
# [[0.00584842]]
# Please throw it into the trash
# 1/1 [==============================] - 0s 36ms/step
# [[1.3400754e-05]]
# Please throw it into the trash
# 1/1 [==============================] - 0s 37ms/step
# [[0.02814534]]
# Please throw it into the trash
# 1/1 [==============================] - 0s 36ms/step
# [[0.00015681]]
# Please throw it into the trash
# 1/1 [==============================] - 0s 45ms/step
# [[0.00577644]]
# Please throw it into the trash
# 1/1 [==============================] - 0s 36ms/step
# [[0.01446614]]
# Please throw it into the trash
# 1/1 [==============================] - 0s 35ms/step
# [[0.01053244]]
# Please throw it into the trash
# 1/1 [==============================] - 0s 41ms/step
# [[0.2714482]]
# Please throw it into the trash
# 1/1 [==============================] - 0s 40ms/step
# [[0.91300005]]
# Please throw it into the trash
# 1/1 [==============================] - 0s 39ms/step
# [[0.8647972]]
# Please throw it into the trash
# 1/1 [==============================] - 0s 37ms/step
# [[0.945514]]
# Please throw it into the trash
# 1/1 [==============================] - 0s 36ms/step
# [[0.8515097]]
# Please throw it into the trash
# 1/1 [==============================] - 0s 40ms/step
# [[0.00148588]]
# Please throw it into the trash
# 1/1 [==============================] - 0s 36ms/step
# [[0.00039305]]
# Please throw it into the trash
# 1/1 [==============================] - 0s 36ms/step
# [[0.99999964]]
# Please throw it into the trash
# 1/1 [==============================] - 0s 37ms/step
# [[3.9739805e-07]]
# Please throw it into the trash
# 1/1 [==============================] - 0s 45ms/step
# [[0.04080896]]
# Please throw it into the trash
# 1/1 [==============================] - 0s 37ms/step
# [[0.00054132]]
# Please throw it into the trash
# 1/1 [==============================] - 0s 36ms/step
# [[1.8632977e-07]]
# Please throw it into the trash
# 1/1 [==============================] - 0s 40ms/step
# [[0.0091689]]
# Please throw it into the trash
# 1/1 [==============================] - 0s 40ms/step
# [[0.04340877]]
# Please throw it into the trash
# 1/1 [==============================] - 0s 36ms/step
# [[0.00033764]]
# Please throw it into the trash
# 1/1 [==============================] - 0s 44ms/step
# [[0.99894756]]
# Please throw it into the trash
# 1/1 [==============================] - 0s 33ms/step
# [[0.8156517]]
# Please throw it into the trash
# 1/1 [==============================] - 0s 37ms/step
# [[0.75668144]]
# Please throw it into the trash
# 1/1 [==============================] - 0s 36ms/step
# [[0.99484044]]
# Please throw it into the trash
# 1/1 [==============================] - 0s 48ms/step
# [[0.6699593]]
# Please throw it into the trash
# 1/1 [==============================] - 0s 40ms/step
# [[0.91455036]]
# Please throw it into the trash
# 1/1 [==============================] - 0s 37ms/step
# [[0.9944929]]
# Please throw it into the trash
# 1/1 [==============================] - 0s 35ms/step
# [[0.97760046]]
# Please throw it into the trash
# 1/1 [==============================] - 0s 40ms/step
# [[0.47938237]]
# Please throw it into the trash
# 1/1 [==============================] - 0s 40ms/step
# [[0.85867065]]
# Please throw it into the trash
# 1/1 [==============================] - 0s 41ms/step
# [[0.95391756]]
# Please throw it into the trash
# 1/1 [==============================] - 0s 38ms/step
# [[0.99905574]]
# Please throw it into the trash
# 1/1 [==============================] - 0s 35ms/step
# [[0.65311414]]
# Please throw it into the trash
# 1/1 [==============================] - 0s 40ms/step
# [[0.9341341]]
# Please throw it into the trash
# 1/1 [==============================] - 0s 41ms/step
# [[0.41124794]]
# Please throw it into the trash
# 1/1 [==============================] - 0s 40ms/step
# [[0.6174714]]
# Please throw it into the trash
# 1/1 [==============================] - 0s 33ms/step
# [[0.9536722]]
# Please throw it into the trash
# 1/1 [==============================] - 0s 45ms/step
# [[0.9873504]]
# Please throw it into the trash
# 1/1 [==============================] - 0s 44ms/step
# [[0.9974095]]
# Please throw it into the trash
# 1/1 [==============================] - 0s 44ms/step
# [[0.3353828]]
# Please throw it into the trash
# 1/1 [==============================] - 0s 39ms/step
# [[0.34667963]]
# Please throw it into the trash
# 1/1 [==============================] - 0s 40ms/step
# [[0.2758983]]
# Please throw it into the trash
# 1/1 [==============================] - 0s 40ms/step
# [[0.02814772]]
# Please throw it into the trash
# 1/1 [==============================] - 0s 50ms/step
# [[0.11946772]]
# Please throw it into the trash
# 1/1 [==============================] - 0s 39ms/step
# [[0.05496718]]
# Please throw it into the trash
# 1/1 [==============================] - 0s 40ms/step
# [[0.34283337]]
# Please throw it into the trash
# 1/1 [==============================] - 0s 35ms/step
# [[0.18811682]]
# Please throw it into the trash
# 1/1 [==============================] - 0s 48ms/step
# [[0.56624794]]
# Please throw it into the trash
# 1/1 [==============================] - 0s 45ms/step
# [[0.30610722]]
# Please throw it into the trash
# 1/1 [==============================] - 0s 43ms/step
# [[0.04846809]]
# Please throw it into the trash
# 1/1 [==============================] - 0s 48ms/step
# [[0.83077914]]
# Please throw it into the trash
# 1/1 [==============================] - 0s 40ms/step
# [[0.99672574]]
# Please throw it into the trash
# 1/1 [==============================] - 0s 45ms/step
# [[0.99636984]]
# Please throw it into the trash
# 1/1 [==============================] - 0s 42ms/step
# [[0.99857205]]
# Please throw it into the trash
# 1/1 [==============================] - 0s 37ms/step
# [[0.99017805]]
# Please throw it into the trash
# 1/1 [==============================] - 0s 34ms/step
# [[0.9988563]]
# Please throw it into the trash
# 1/1 [==============================] - 0s 43ms/step
# [[0.99959964]]
# Please throw it into the trash
# 1/1 [==============================] - 0s 40ms/step
# [[0.9970219]]
# Please throw it into the trash
# 1/1 [==============================] - 0s 40ms/step
# [[0.9984783]]
# Please throw it into the trash
# 1/1 [==============================] - 0s 42ms/step
# [[0.7542011]]
# Please throw it into the trash
# 1/1 [==============================] - 0s 43ms/step
# [[0.9374984]]
# Please throw it into the trash
# 1/1 [==============================] - 0s 44ms/step
# [[0.98611176]]
# Please throw it into the trash
# 1/1 [==============================] - 0s 41ms/step
# [[0.9953342]]
# Please throw it into the trash
# 1/1 [==============================] - 0s 38ms/step
# [[0.03399733]]
# Please throw it into the trash
# 1/1 [==============================] - 0s 47ms/step
# [[0.00517139]]
# Please throw it into the trash
# 1/1 [==============================] - 0s 37ms/step
# [[0.01093337]]
# Please throw it into the trash
# 1/1 [==============================] - 0s 33ms/step
# [[0.4877458]]
# Please throw it into the trash
# 1/1 [==============================] - 0s 40ms/step
# [[0.940316]]
# Please throw it into the trash
# 1/1 [==============================] - 0s 45ms/step
# [[5.525421e-05]]
# Please throw it into the trash
# 1/1 [==============================] - 0s 37ms/step
# [[0.98416275]]
# Please throw it into the trash
# 1/1 [==============================] - 0s 36ms/step
# [[0.03181808]]
# Please throw it into the trash
# 1/1 [==============================] - 0s 38ms/step
# [[0.8915361]]
# Please throw it into the trash
# 1/1 [==============================] - 0s 41ms/step
# [[0.06663614]]
# Please throw it into the trash
# 1/1 [==============================] - 0s 45ms/step
# [[0.706247]]
# Please throw it into the trash
# 1/1 [==============================] - 0s 34ms/step
# [[0.96431684]]
# Please throw it into the trash
# 1/1 [==============================] - 0s 38ms/step
# [[0.00061797]]
# Please throw it into the trash
# 1/1 [==============================] - 0s 41ms/step
# [[0.9999932]]
# Please throw it into the trash
# 1/1 [==============================] - 0s 37ms/step
# [[0.99895376]]
# Please throw it into the trash
# 1/1 [==============================] - 0s 39ms/step
# [[0.591991]]
# Please throw it into the trash
# 1/1 [==============================] - 0s 40ms/step
# [[0.6678205]]
# Please throw it into the trash
# 1/1 [==============================] - 0s 40ms/step
# [[0.97545666]]
# Please throw it into the trash
# 1/1 [==============================] - 0s 43ms/step
# [[0.91903144]]
# Please throw it into the trash
# 1/1 [==============================] - 0s 34ms/step
# [[0.8497057]]
# Please throw it into the trash
# 1/1 [==============================] - 0s 39ms/step
# [[0.41563675]]
# Please throw it into the trash
# 1/1 [==============================] - 0s 37ms/step
# [[0.00111976]]
# Please throw it into the trash
# 1/1 [==============================] - 0s 41ms/step
# [[0.08364329]]
# Please throw it into the trash
# 1/1 [==============================] - 0s 52ms/step
# [[0.00418956]]
# Please throw it into the trash
# 1/1 [==============================] - 0s 49ms/step
# [[0.1239872]]
# Please throw it into the trash
# 1/1 [==============================] - 0s 41ms/step
# [[0.01007677]]
# Please throw it into the trash
# 1/1 [==============================] - 0s 44ms/step
# [[0.00252215]]
# Please throw it into the trash
# 1/1 [==============================] - 0s 44ms/step
# [[0.00261666]]
# Please throw it into the trash
# 1/1 [==============================] - 0s 37ms/step
# [[0.8572649]]
# Please throw it into the trash
# 1/1 [==============================] - 0s 45ms/step
# [[0.9888728]]
# Please throw it into the trash
# 1/1 [==============================] - 0s 39ms/step
# [[0.94725174]]
# Please throw it into the trash
# 1/1 [==============================] - 0s 40ms/step
# [[0.03301619]]
# Please throw it into the trash
# 1/1 [==============================] - 0s 35ms/step
# [[0.13260518]]
# Please throw it into the trash
# 1/1 [==============================] - 0s 40ms/step
# [[0.02471003]]
# Please throw it into the trash
# 1/1 [==============================] - 0s 41ms/step
# [[0.22958583]]
# Please throw it into the trash
# 1/1 [==============================] - 0s 39ms/step
# [[0.95145476]]
# Please throw it into the trash
# 1/1 [==============================] - 0s 36ms/step
# [[0.46729305]]
# Please throw it into the trash
# 1/1 [==============================] - 0s 42ms/step
# [[0.79914904]]
# Please throw it into the trash
# 1/1 [==============================] - 0s 44ms/step
# [[0.9581577]]
# Please throw it into the trash
# 1/1 [==============================] - 0s 43ms/step
# [[0.90877444]]
# Please throw it into the trash
# 1/1 [==============================] - 0s 36ms/step
# [[0.19268201]]
# Please throw it into the trash
# 1/1 [==============================] - 0s 41ms/step
# [[0.98088616]]
# Please throw it into the trash
# 1/1 [==============================] - 0s 42ms/step
# [[0.99945015]]
# Please throw it into the trash
# 1/1 [==============================] - 0s 39ms/step
# [[0.97924554]]
# Please throw it into the trash
# 1/1 [==============================] - 0s 43ms/step
# [[0.9545069]]
# Please throw it into the trash
# 1/1 [==============================] - 0s 41ms/step
# [[0.99050224]]
# Please throw it into the trash
# 1/1 [==============================] - 0s 40ms/step
# [[0.10995571]]
# Please throw it into the trash
# 1/1 [==============================] - 0s 44ms/step
# [[0.9421321]]
# Please throw it into the trash
# 1/1 [==============================] - 0s 44ms/step
# [[0.97366416]]
# Please throw it into the trash
# 1/1 [==============================] - 0s 41ms/step
# [[0.99926686]]
# Please throw it into the trash
# 1/1 [==============================] - 0s 41ms/step
# [[0.9989971]]
# Please throw it into the trash
# 1/1 [==============================] - 0s 32ms/step
# [[0.97081995]]
# Please throw it into the trash
# 1/1 [==============================] - 0s 41ms/step
# [[0.9209843]]
# Please throw it into the trash
# 1/1 [==============================] - 0s 40ms/step
# [[0.4992884]]
# Please throw it into the trash
# 1/1 [==============================] - 0s 36ms/step
# [[0.5681694]]
# Please throw it into the trash
# 1/1 [==============================] - 0s 37ms/step
# [[0.9851794]]
# Please throw it into the trash
# 1/1 [==============================] - 0s 48ms/step
# [[0.00778075]]
# Please throw it into the trash
# 1/1 [==============================] - 0s 46ms/step
# [[0.00906329]]
# Please throw it into the trash
# 1/1 [==============================] - 0s 42ms/step
# [[1.]]
# Please throw it into the trash
# 1/1 [==============================] - 0s 41ms/step
# [[0.8756167]]
# Please throw it into the trash
# 1/1 [==============================] - 0s 35ms/step
# [[0.99930835]]
# Please throw it into the trash
# 1/1 [==============================] - 0s 38ms/step
# [[0.99926984]]
# Please throw it into the trash
# 1/1 [==============================] - 0s 41ms/step
# [[0.91994107]]
# Please throw it into the trash
# 1/1 [==============================] - 0s 33ms/step
# [[0.9877867]]
# Please throw it into the trash
# 1/1 [==============================] - 0s 37ms/step
# [[0.91331184]]
# Please throw it into the trash
# 1/1 [==============================] - 0s 39ms/step
# [[0.99851364]]
# Please throw it into the trash
# 1/1 [==============================] - 0s 38ms/step
# [[1.]]
# Please throw it into the trash
# 1/1 [==============================] - 0s 40ms/step
# [[0.9999998]]
# Please throw it into the trash
# 1/1 [==============================] - 0s 41ms/step
# [[1.]]
# Please throw it into the trash
# 1/1 [==============================] - 0s 40ms/step
# [[0.9999995]]
# Please throw it into the trash
# 1/1 [==============================] - 0s 38ms/step
# [[0.9999999]]
# Please throw it into the trash
# 1/1 [==============================] - 0s 43ms/step
# [[1.]]
# Please throw it into the trash
# 1/1 [==============================] - 0s 38ms/step
# [[0.9999997]]
# Please throw it into the trash
# 1/1 [==============================] - 0s 48ms/step
# [[1.]]
# Please throw it into the trash
# 1/1 [==============================] - 0s 41ms/step
# [[1.]]
# Please throw it into the trash
# 1/1 [==============================] - 0s 34ms/step
# [[0.99999994]]
# Please throw it into the trash
# 1/1 [==============================] - 0s 40ms/step
# [[1.]]
# Please throw it into the trash
# 1/1 [==============================] - 0s 42ms/step
# [[0.9999971]]
# Please throw it into the trash
# 1/1 [==============================] - 0s 33ms/step
# [[1.]]
# Please throw it into the trash
# 1/1 [==============================] - 0s 44ms/step
# [[1.]]
# Please throw it into the trash
# 1/1 [==============================] - 0s 40ms/step
# [[1.]]
# Please throw it into the trash
# 1/1 [==============================] - 0s 48ms/step
# [[1.]]
# Please throw it into the trash
# 1/1 [==============================] - 0s 33ms/step
# [[1.]]
# Please throw it into the trash
# 1/1 [==============================] - 0s 38ms/step
# [[0.9999999]]
# Please throw it into the trash
# 1/1 [==============================] - 0s 37ms/step
# [[0.99999964]]
# Please throw it into the trash
# 1/1 [==============================] - 0s 36ms/step
# [[0.99801433]]
# Please throw it into the trash
# 1/1 [==============================] - 0s 36ms/step
# [[0.9997939]]
# Please throw it into the trash
# 1/1 [==============================] - 0s 36ms/step
# [[0.9523155]]
# Please throw it into the trash
# 1/1 [==============================] - 0s 43ms/step
# [[0.00051204]]
# Please throw it into the trash
# 1/1 [==============================] - 0s 36ms/step
# [[0.992955]]
# Please throw it into the trash
# 1/1 [==============================] - 0s 45ms/step
# [[0.7021418]]
# Please throw it into the trash
# 1/1 [==============================] - 0s 43ms/step
# [[0.59765494]]
# Please throw it into the trash
# 1/1 [==============================] - 0s 44ms/step
# [[0.06918031]]
# Please throw it into the trash
# 1/1 [==============================] - 0s 39ms/step
# [[0.8958127]]
# Please throw it into the trash
# 1/1 [==============================] - 0s 41ms/step
# [[0.99996096]]
# Please throw it into the trash
# 1/1 [==============================] - 0s 39ms/step
# [[0.87618864]]
# Please throw it into the trash
